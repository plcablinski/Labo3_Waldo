# %%
#%pip install optuna-dashboard

import optuna
import optuna_dashboard

storage = "sqlite:///C:/Users/waldo/Dropbox/Maestría Ciencia de Datos/Labo 3/Proceso/optuna_lgbm_study.db"

optuna_dashboard.run_server(storage)
# Out:
# Bottle v0.13.3 server starting up (using WSGIRefServer())...
# Listening on http://localhost:8080/
# Hit Ctrl-C to quit.
#
# 127.0.0.1 - - [24/Jun/2025 18:17:06] "GET / HTTP/1.1" 302 0
# 127.0.0.1 - - [24/Jun/2025 18:17:09] "GET /api/studies HTTP/1.1" 200 514
# 127.0.0.1 - - [24/Jun/2025 18:17:58] "GET /api/studies HTTP/1.1" 200 514
# 127.0.0.1 - - [24/Jun/2025 18:18:02] "GET /api/studies HTTP/1.1" 200 514
# 127.0.0.1 - - [24/Jun/2025 18:18:53] "GET /api/studies HTTP/1.1" 200 514
# 127.0.0.1 - - [24/Jun/2025 18:20:01] "GET /api/studies HTTP/1.1" 200 638
# 127.0.0.1 - - [24/Jun/2025 18:20:03] "GET /api/studies/5/param_importances?evaluator=ped_anova HTTP/1.1" 200 27
# 127.0.0.1 - - [24/Jun/2025 18:20:03] "GET /api/studies/5?after=0 HTTP/1.1" 200 3093
# 127.0.0.1 - - [24/Jun/2025 18:20:03] "GET /api/meta HTTP/1.1" 200 63
# 127.0.0.1 - - [24/Jun/2025 18:20:17] "GET /api/studies/5?after=0 HTTP/1.1" 200 3093
# ...
