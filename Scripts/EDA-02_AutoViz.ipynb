# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>AutoViz realiza la visualización automática de cualquier conjunto de datos con una línea</strong></p>

# %%
import matplotlib
print(f'Matplotlib version: {matplotlib.__version__}')
# Out:
# Matplotlib version: 3.10.3

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
AV = AutoViz_Class()

# %%
# %matplotlib inline
df = AV.AutoViz('finalitoul.csv')
# Out:
#     max_rows_analyzed is smaller than dataset shape 16763760...
#         randomly sampled 150000 rows from read CSV file
# Shape of your Data Set loaded: (150000, 13)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  4
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  5
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     13 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# Since Number of Rows in data 150000 exceeds maximum, randomly sampling 150000 rows for EDA...
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_247bf_row0_col0, #T_247bf_row0_col2, #T_247bf_row0_col3, #T_247bf_row0_col4, #T_247bf_row0_col5, #T_247bf_row1_col0, #T_247bf_row1_col2, #T_247bf_row1_col3, #T_247bf_row1_col4, #T_247bf_row1_col5, #T_247bf_row2_col0, #T_247bf_row2_col2, #T_247bf_row2_col3, #T_247bf_row2_col4, #T_247bf_row2_col5, #T_247bf_row3_col0, #T_247bf_row3_col2, #T_247bf_row3_col3, #T_247bf_row3_col4, #T_247bf_row3_col5, #T_247bf_row4_col0, #T_247bf_row4_col2, #T_247bf_row4_col3, #T_247bf_row4_col4, #T_247bf_row4_col5, #T_247bf_row5_col0, #T_247bf_row5_col2, #T_247bf_row5_col3, #T_247bf_row5_col4, #T_247bf_row5_col5, #T_247bf_row6_col0, #T_247bf_row6_col2, #T_247bf_row6_col3, #T_247bf_row6_col4, #T_247bf_row6_col5, #T_247bf_row7_col0, #T_247bf_row7_col2, #T_247bf_row7_col3, #T_247bf_row7_col4, #T_247bf_row7_col5, #T_247bf_row8_col0, #T_247bf_row8_col2, #T_247bf_row8_col3, #T_247bf_row8_col4, #T_247bf_row8_col5, #T_247bf_row9_col0, #T_247bf_row9_col2, #T_247bf_row9_col3, #T_247bf_row9_col4, #T_247bf_row9_col5, #T_247bf_row10_col0, #T_247bf_row10_col2, #T_247bf_row10_col3, #T_247bf_row10_col4, #T_247bf_row10_col5, #T_247bf_row11_col0, #T_247bf_row11_col2, #T_247bf_row11_col3, #T_247bf_row11_col4, #T_247bf_row11_col5, #T_247bf_row12_col0, #T_247bf_row12_col2, #T_247bf_row12_col3, #T_247bf_row12_col4, #T_247bf_row12_col5 {
#   font-family: Segoe UI;
# }
# #T_247bf_row0_col1, #T_247bf_row1_col1, #T_247bf_row2_col1, #T_247bf_row3_col1, #T_247bf_row4_col1, #T_247bf_row5_col1, #T_247bf_row6_col1, #T_247bf_row7_col1, #T_247bf_row8_col1, #T_247bf_row9_col1, #T_247bf_row10_col1, #T_247bf_row11_col1, #T_247bf_row12_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_247bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_247bf_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_247bf_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_247bf_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_247bf_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_247bf_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_247bf_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_247bf_level0_row0" class="row_heading level0 row0" >customer_id</th>
#       <td id="T_247bf_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_247bf_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_247bf_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_247bf_row0_col3" class="data row0 col3" >10001.000000</td>
#       <td id="T_247bf_row0_col4" class="data row0 col4" >10637.000000</td>
#       <td id="T_247bf_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row1" class="row_heading level0 row1" >product_id</th>
#       <td id="T_247bf_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_247bf_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_247bf_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_247bf_row1_col3" class="data row1 col3" >20001.000000</td>
#       <td id="T_247bf_row1_col4" class="data row1 col4" >21276.000000</td>
#       <td id="T_247bf_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row2" class="row_heading level0 row2" >periodo</th>
#       <td id="T_247bf_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_247bf_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_247bf_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_247bf_row2_col3" class="data row2 col3" ></td>
#       <td id="T_247bf_row2_col4" class="data row2 col4" ></td>
#       <td id="T_247bf_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row3" class="row_heading level0 row3" >plan_precios_cuidados</th>
#       <td id="T_247bf_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_247bf_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_247bf_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_247bf_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_247bf_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_247bf_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row4" class="row_heading level0 row4" >cust_request_qty</th>
#       <td id="T_247bf_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_247bf_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_247bf_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_247bf_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_247bf_row4_col4" class="data row4 col4" >85.000000</td>
#       <td id="T_247bf_row4_col5" class="data row4 col5" >Column has 20615 outliers greater than upper bound (0.00) or lower than lower bound(0.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row5" class="row_heading level0 row5" >cust_request_tn</th>
#       <td id="T_247bf_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_247bf_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_247bf_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_247bf_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_247bf_row5_col4" class="data row5 col4" >287.365020</td>
#       <td id="T_247bf_row5_col5" class="data row5 col5" >Column has 20615 outliers greater than upper bound (0.00) or lower than lower bound(0.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row6" class="row_heading level0 row6" >tn</th>
#       <td id="T_247bf_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_247bf_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_247bf_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_247bf_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_247bf_row6_col4" class="data row6 col4" >287.141820</td>
#       <td id="T_247bf_row6_col5" class="data row6 col5" >Column has 20615 outliers greater than upper bound (0.00) or lower than lower bound(0.00). Cap them or remove them., Column has a high correlation with ['cust_request_tn']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row7" class="row_heading level0 row7" >stock_final</th>
#       <td id="T_247bf_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_247bf_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_247bf_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_247bf_row7_col3" class="data row7 col3" >-13.666560</td>
#       <td id="T_247bf_row7_col4" class="data row7 col4" >1562.024480</td>
#       <td id="T_247bf_row7_col5" class="data row7 col5" >Column has 27087 outliers greater than upper bound (6.92) or lower than lower bound(-4.15). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row8" class="row_heading level0 row8" >cat1</th>
#       <td id="T_247bf_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_247bf_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_247bf_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_247bf_row8_col3" class="data row8 col3" ></td>
#       <td id="T_247bf_row8_col4" class="data row8 col4" ></td>
#       <td id="T_247bf_row8_col5" class="data row8 col5" >1 rare categories: ['REF']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_247bf_level0_row9" class="row_heading level0 row9" >cat2</th>
#       <td id="T_247bf_row9_col0" class="data row9 col0" >object</td>
#       <td id="T_247bf_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_247bf_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_247bf_row9_col3" class="data row9 col3" ></td>
#       <td id="T_247
# Number of All Scatter Plots = 10
# All Plots done
# Time to run AutoViz = 35 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>
